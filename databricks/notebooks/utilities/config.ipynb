# %% [markdown]
# # Shared Config
#
# Common paths and business rules used by all Databricks notebooks.

# %%
CATALOG = "workspace"
SCHEMA = "customer_analytics"
VOLUME = "data_files"

BASE_PATH = f"/Volumes/{CATALOG}/{SCHEMA}/{VOLUME}"

RAW_PATH = f"{BASE_PATH}/raw/customer_events"
BRONZE_PATH = f"{BASE_PATH}/bronze/customer_events"
SILVER_PATH = f"{BASE_PATH}/silver/customer_events"
GOLD_PATH = f"{BASE_PATH}/gold"

BRONZE_CHECKPOINT = f"{BASE_PATH}/checkpoints/bronze/customer_events"
SILVER_CHECKPOINT = f"{BASE_PATH}/checkpoints/silver/customer_events"

VALID_EVENT_TYPES = [
    "user_login",
    "product_view",
    "cart_add",
    "checkout",
    "payment_success",
    "payment_failed",
]
